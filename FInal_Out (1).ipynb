# %%
import pandas as pd
import numpy as np

# %%
#initial Dataset 
df = pd.read_csv('/Users/kalyanvikkurthi/Downloads/US_Accidents_Dec21_updated.csv')

# %%
df.head(5)
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df['temp'] = 1
gk = df.groupby(['State','City']).count()
y = gk.sort_values(by=['temp'], ascending=False).head(20)
y
# y.to_csv('Top 20.csv')
# Out:
# /var/folders/c8/tlssp4z95q7dmbd5pc2b1xww0000gn/T/ipykernel_36379/2658249989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp'] = 1
#                         ID  Severity  Start_Time  End_Time  Start_Lat  \
# State City
# FL    Miami         106896    106896      106896    106896     106896
# CA    Los Angeles    68956     68956       68956     68956      68956
# FL    Orlando        54654     54654       54654     54654      54654
# TX    Dallas         41615     41615       41615     41615      41615
#       Houston        39366     39366       39366     39366      39366
# NC    Charlotte      32998     32998       32998     32998      32998
# CA    Sacramento     32559     32559       32559     32559      32559
# ...

# %%
top_20 = pd.read_csv('/Users/kalyanvikkurthi/Top 20.csv')
Top_20_states = list((top_20['State']).head(20))
Top_20_cities = list(top_20['City'].head(20))
print("The top 20 states are : ", Top_20_states)
print("The top 20 cities are : ", Top_20_cities)
# Out:
# The top 20 states are :  ['FL', 'CA', 'FL', 'TX', 'TX', 'NC', 'CA', 'CA', 'NC', 'MN', 'OR', 'TN', 'LA', 'TX', 'AZ', 'MN', 'LA', 'GA', 'FL', 'AZ']
# The top 20 cities are :  ['Miami', 'Los Angeles', 'Orlando', 'Dallas', 'Houston', 'Charlotte', 'Sacramento', 'San Diego', 'Raleigh', 'Minneapolis', 'Portland', 'Nashville', 'Baton Rouge', 'Austin', 'Phoenix', 'Saint Paul', 'New Orleans', 'Atlanta', 'Jacksonville', 'Tucson']

# %%
df.isna().sum()["State"]
# Out:
# 0

# %%
df.isna().sum()["City"]
# Out:
# 0

# %%
out_list = []
for i in range(len(Top_20_states)):
    print(Top_20_states[i])
    print(Top_20_cities[i])
    z = df[df['State'] == Top_20_states[i]]
    z = z[z['City'] == Top_20_cities[i]]
    out_list.append(z)
result = pd.concat(out_list)
# result.to_csv('updated.csv')
result
# Out:
# FL
# Miami
# CA
# Los Angeles
# FL
# Orlando
# TX
# Dallas
# TX
# Houston
# NC
# Charlotte
# CA
# Sacramento
# CA
# San Diego
# NC
# Raleigh
# MN
# Minneapolis
# OR
# Portland
# TN
# Nashville
# LA
# Baton Rouge
# TX
# Austin
# AZ
# Phoenix
# MN
# Saint Paul
# LA
# New Orleans
# GA
# Atlanta
# FL
# Jacksonville
# AZ
# Tucson
#                 ID  Severity           Start_Time             End_Time  \
# 31596      A-31597         2  2016-11-30 16:35:52  2016-11-30 22:35:52
# 31660      A-31661         2  2016-11-30 18:35:52  2016-12-01 00:35:52
# 31734      A-31735         2  2016-12-01 05:51:51  2016-12-01 11:51:51
# 31735      A-31736         3  2016-12-01 06:03:23  2016-12-01 12:03:23
# 31805      A-31806         2  2016-12-01 08:21:46  2016-12-01 14:21:46
# ...            ...       ...                  ...                  ...
# 2837407  A-2837408         3  2019-08-06 19:37:21  2019-08-06 20:05:27
# 2837408  A-2837409         3  2019-08-06 19:37:21  2019-08-06 20:05:27
# ...

# %%
result.shape
# Out:
# (619912, 48)

# %%
top_cities=result['City'].value_counts().head(20)
top_cities
# Out:
# Miami           106896
# Los Angeles      68956
# Orlando          54654
# Dallas           41615
# Houston          39366
# Charlotte        32998
# Sacramento       32559
# San Diego        26627
# Raleigh          22837
# Minneapolis      22768
# Portland         20563
# Nashville        20160
# Baton Rouge      18182
# Austin           17928
# Phoenix          16940
# Saint Paul       16727
# New Orleans      16251
# Atlanta          15614
# Jacksonville     14472
# Tucson           13799
# Name: City, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(y=top_cities.index, x=top_cities)
plt.title("Cities in US reported most accident cases",size=17,color="grey")
plt.xlabel('City')
plt.ylabel('No. of cases')
# Out:
# Text(0, 0.5, 'No. of cases')

# %%
plt.figure(figsize=(12,12))
plt.pie(top_cities,labels=top_cities.index,autopct='%.2f%%')
plt.title("Cities in US reported most accident cases",size=17,color="grey")
# Out:
# Text(0.5, 1.0, 'Cities in US reported most accident cases')

# %%
#Count the number of Null values
result.isnull().sum().sort_values(ascending=False)
# Out:
# Number               332672
# Precipitation(in)     93351
# Wind_Chill(F)         88029
# Wind_Speed(mph)       21280
# Wind_Direction         6859
#                       ...
# County                    0
# State                     0
# Zipcode                   0
# Country                   0
# temp                      0
# Length: 48, dtype: int64

# %%
# percentage of missing values column wise

per_of_missing_val_in_each_col= (result.isnull().sum().sort_values(ascending=False)/len(z))*100
per_of_missing_val_in_each_col
# Out:
# Number               2410.841365
# Precipitation(in)     676.505544
# Wind_Chill(F)         637.937532
# Wind_Speed(mph)       154.214073
# Wind_Direction         49.706500
#                         ...
# County                  0.000000
# State                   0.000000
# Zipcode                 0.000000
# Country                 0.000000
# temp                    0.000000
# Length: 48, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,9))
sns.barplot(y=per_of_missing_val_in_each_col.index, x=per_of_missing_val_in_each_col)
plt.title("Percentage of null values in the dataset",size=17,color="grey")
plt.xlabel('Percentage (%)')
plt.ylabel('Columns')
# Out:
# Text(0, 0.5, 'Columns')

# %%
result.shape
# Out:
# (619912, 48)

# %%
per_of_missing_val_in_each_col[per_of_missing_val_in_each_col>50.0]
# Out:
# Number               2410.841365
# Precipitation(in)     676.505544
# Wind_Chill(F)         637.937532
# Wind_Speed(mph)       154.214073
# dtype: float64

# %%
#we will use interpolate to reduce the number of NULL values 
Final_Dataset=result.interpolate()

# %%
#after filling the null values with the interpolate -> to reduce the null values
Final_Dataset.isnull().sum().sort_values(ascending=False)
# Out:
# Wind_Direction       6859
# Weather_Condition    3809
# Wind_Chill(F)        3447
# Weather_Timestamp    2318
# Airport_Code           12
#                      ...
# Country                 0
# Timezone                0
# Temperature(F)          0
# Humidity(%)             0
# temp                    0
# Length: 48, dtype: int64

# %%
Final_Dataset.shape
# Out:
# (619912, 48)
